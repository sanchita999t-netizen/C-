# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchita999t-netizen/C-/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME: Sanchitaraje Prasad Tanpure
# Roll NO  : 26 And SECTION : F
# PRACTICAL NO :1

# %% [markdown]
# AIM 1 : CREATE A LIST OF YOUR FAVOURITE MOVIES AND PRINT THE THIRD MOVIE

# %%
favouritemovies =[" 3 idiots ", " taqdeer ","  tare zamen par "]
print(favouritemovies[2])

# %% [markdown]
# AIM 2: ADD A NEW MOVIE TO THE LIST AND PRINT THE UPDATED LIST

# %%
favouritemovies.append("chaava")
print(favouritemovies)

# %% [markdown]
# AIM:3 REMOVE THE SECOND MOVIE FROM THE LIST AND PRINT THE UPDATED LIST

# %%
favouritemovies.pop(1)
print(favouritemovies)

# %% [markdown]
# AIM :4 SORT THE LIST IN ALPHABETICAL ORDER AND PRINT THE SORTED LIST

# %%
favouritemovies.sort()
print(favouritemovies)

# %% [markdown]
# AIM :5 CREATE A NEW LIST THAT CONTAINS ONLY THE FIRST AND LAST MOVIE IN THE ORIGINALLIST AND PRINT IT

# %%
newlist = [favouritemovies[0],favouritemovies[-1]]
print(newlist)
